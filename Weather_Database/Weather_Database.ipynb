# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90.00,90.00, size = 2000)
lngs = np.random.uniform(-180.00,180.00, size = 2000)

lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#4. Get the nearest city using the citipy module.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 753

# %%
#5. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bria
# Processing Record 2 of Set 1 | ancud
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | lavrentiya
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | comodoro rivadavia
# Processing Record 10 of Set 1 | bulawayo
# Processing Record 11 of Set 1 | lida
# Processing Record 12 of Set 1 | pisco
# Processing Record 13 of Set 1 | koryazhma
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 1 | senneterre
# Processing Record 17 of Set 1 | kenora
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | sakakah
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | periceiu
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | tocopilla
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | jaguarari
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | ouesso
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | chernyshevskiy
# Processing Record 35 of Set 1 | waingapu
# Processing Record 36 of Set 1 | usakos
# Processing Record 37 of Set 1 | fort nelson
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | bilibino
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | bandar-e lengeh
# Processing Record 44 of Set 1 | buraydah
# Processing Record 45 of Set 1 | erenhot
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | adrar
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | manuk mangkaw
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | clyde river
# Processing Record 6 of Set 2 | nanortalik
# Processing Record 7 of Set 2 | port blair
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | ust-ilimsk
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | valls
# Processing Record 12 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 2 | matara
# Processing Record 14 of Set 2 | djibo
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | mamallapuram
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | lata
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | hualmay
# Processing Record 23 of Set 2 | san patricio
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | lamu
# Processing Record 28 of Set 2 | port augusta
# Processing Record 29 of Set 2 | cayenne
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | richards bay
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | engels
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | terrace
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | papara
# Processing Record 39 of Set 2 | birin
# Processing Record 40 of Set 2 | sao joao da barra
# Processing Record 41 of Set 2 | elmadag
# Processing Record 42 of Set 2 | severodvinsk
# Processing Record 43 of Set 2 | salinopolis
# Processing Record 44 of Set 2 | vila franca do campo
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | padang
# Processing Record 48 of Set 2 | srednekolymsk
# Processing Record 49 of Set 2 | cabra
# Processing Record 50 of Set 2 | kudahuvadhoo
# Processing Record 1 of Set 3 | cabedelo
# Processing Record 2 of Set 3 | khorixas
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | ganta
# Processing Record 5 of Set 3 | thinadhoo
# Processing Record 6 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 3 | contamana
# Processing Record 8 of Set 3 | mangrol
# Processing Record 9 of Set 3 | rewa
# Processing Record 10 of Set 3 | hay river
# Processing Record 11 of Set 3 | mount gambier
# Processing Record 12 of Set 3 | alofi
# Processing Record 13 of Set 3 | ewa beach
# Processing Record 14 of Set 3 | xining
# Processing Record 15 of Set 3 | kosa
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | pemangkat
# Processing Record 18 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 3 | magadan
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | akyab
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | henties bay
# Processing Record 24 of Set 3 | klaksvik
# Processing Record 25 of Set 3 | tianpeng
# Processing Record 26 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 3 | grand gaube
# Processing Record 29 of Set 3 | ponta do sol
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | ketchikan
# Processing Record 32 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 3 | georgetown
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | phalaborwa
# Processing Record 37 of Set 3 | redding
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | andros town
# Processing Record 43 of Set 3 | nouadhibou
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | tezu
# Processing Record 47 of Set 3 | beidao
# Processing Record 48 of Set 3 | tessalit
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | rawson
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | olinda
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | kapaa
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | pizarro
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | mahibadhoo
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | arcata
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | hambantota
# Processing Record 17 of Set 4 | noumea
# Processing Record 18 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 4 | tulagi
# Processing Record 20 of Set 4 | kitimat
# Processing Record 21 of Set 4 | torbay
# Processing Record 22 of Set 4 | duluth
# Processing Record 23 of Set 4 | forte dei marmi
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | kuching
# Processing Record 26 of Set 4 | christchurch
# Processing Record 27 of Set 4 | eyl
# Processing Record 28 of Set 4 | rosetown
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | karasuk
# Processing Record 31 of Set 4 | avarua
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | kamenka
# Processing Record 34 of Set 4 | laguna
# Processing Record 35 of Set 4 | moroni
# Processing Record 36 of Set 4 | katherine
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | dingle
# Processing Record 39 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 4 | deputatskiy
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | capiibary
# Processing Record 46 of Set 4 | nishihara
# Processing Record 47 of Set 4 | kota bahru
# Processing Record 48 of Set 4 | pont-a-mousson
# Processing Record 49 of Set 4 | cacu
# Processing Record 50 of Set 4 | husyatyn
# Processing Record 1 of Set 5 | te anau
# Processing Record 2 of Set 5 | bambous virieux
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | bangassou
# Processing Record 5 of Set 5 | sassandra
# Processing Record 6 of Set 5 | bagdarin
# Processing Record 7 of Set 5 | mahebourg
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | butaritari
# Processing Record 10 of Set 5 | opuwo
# Processing Record 11 of Set 5 | cabo san lucas
# Processing Record 12 of Set 5 | mecca
# Processing Record 13 of Set 5 | umm kaddadah
# Processing Record 14 of Set 5 | astoria
# Processing Record 15 of Set 5 | verkh-usugli
# Processing Record 16 of Set 5 | beloha
# Processing Record 17 of Set 5 | verkhnyaya sinyachikha
# Processing Record 18 of Set 5 | yumen
# Processing Record 19 of Set 5 | kangalassy
# Processing Record 20 of Set 5 | makakilo city
# Processing Record 21 of Set 5 | passo fundo
# Processing Record 22 of Set 5 | marawi
# Processing Record 23 of Set 5 | bubaque
# Processing Record 24 of Set 5 | baykit
# Processing Record 25 of Set 5 | khatanga
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | roros
# Processing Record 28 of Set 5 | batemans bay
# Processing Record 29 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 5 | boa vista
# Processing Record 31 of Set 5 | izmir
# Processing Record 32 of Set 5 | acari
# Processing Record 33 of Set 5 | okhotsk
# Processing Record 34 of Set 5 | aranos
# Processing Record 35 of Set 5 | berdigestyakh
# Processing Record 36 of Set 5 | homer
# Processing Record 37 of Set 5 | yuci
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | egvekinot
# Processing Record 40 of Set 5 | pasinler
# Processing Record 41 of Set 5 | kysyl-syr
# Processing Record 42 of Set 5 | mar del plata
# Processing Record 43 of Set 5 | belmonte
# Processing Record 44 of Set 5 | hun
# Processing Record 45 of Set 5 | adre
# Processing Record 46 of Set 5 | pekan
# Processing Record 47 of Set 5 | grong
# Processing Record 48 of Set 5 | kirakira
# Processing Record 49 of Set 5 | athabasca
# Processing Record 50 of Set 5 | ahipara
# Processing Record 1 of Set 6 | san jeronimo
# Processing Record 2 of Set 6 | kasane
# Processing Record 3 of Set 6 | mandalgovi
# Processing Record 4 of Set 6 | taloqan
# Processing Record 5 of Set 6 | guerrero negro
# Processing Record 6 of Set 6 | axim
# Processing Record 7 of Set 6 | sitka
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | sete
# Processing Record 10 of Set 6 | genhe
# Processing Record 11 of Set 6 | pasighat
# Processing Record 12 of Set 6 | mae sai
# Processing Record 13 of Set 6 | sechura
# Processing Record 14 of Set 6 | sorland
# Processing Record 15 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 6 | zhigansk
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | san quintin
# Processing Record 19 of Set 6 | nuevo laredo
# Processing Record 20 of Set 6 | vangaindrano
# Processing Record 21 of Set 6 | naze
# Processing Record 22 of Set 6 | ixtapa
# Processing Record 23 of Set 6 | mount isa
# Processing Record 24 of Set 6 | umm lajj
# Processing Record 25 of Set 6 | agirish
# Processing Record 26 of Set 6 | tahta
# Processing Record 27 of Set 6 | lima
# Processing Record 28 of Set 6 | vanavara
# Processing Record 29 of Set 6 | lhokseumawe
# Processing Record 30 of Set 6 | nabire
# Processing Record 31 of Set 6 | flinders
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | kulhudhuffushi
# Processing Record 34 of Set 6 | hofn
# Processing Record 35 of Set 6 | rantepao
# Processing Record 36 of Set 6 | victor harbor
# Processing Record 37 of Set 6 | waipawa
# Processing Record 38 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 6 | wajima
# Processing Record 40 of Set 6 | fare
# Processing Record 41 of Set 6 | mumbwa
# Processing Record 42 of Set 6 | mezen
# Processing Record 43 of Set 6 | doembang nangbuat
# Processing Record 44 of Set 6 | acarau
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | dudinka
# Processing Record 47 of Set 6 | ishigaki
# Processing Record 48 of Set 6 | kailua
# Processing Record 49 of Set 6 | mirzapur
# Processing Record 50 of Set 6 | bowen
# Processing Record 1 of Set 7 | santiago del estero
# Processing Record 2 of Set 7 | hailar
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | ambulu
# Processing Record 5 of Set 7 | hunterville
# Processing Record 6 of Set 7 | puerto baquerizo moreno
# Processing Record 7 of Set 7 | broken hill
# Processing Record 8 of Set 7 | saskylakh
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | bandarbeyla
# Processing Record 11 of Set 7 | talaya
# Processing Record 12 of Set 7 | sola
# Processing Record 13 of Set 7 | hastings
# Processing Record 14 of Set 7 | bershet
# Processing Record 15 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 7 | tuatapere
# Processing Record 17 of Set 7 | pestravka
# Processing Record 18 of Set 7 | turukhansk
# Processing Record 19 of Set 7 | cherskiy
# Processing Record 20 of Set 7 | maniitsoq
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | antofagasta
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | suez
# Processing Record 25 of Set 7 | nakhon thai
# Processing Record 26 of Set 7 | haines junction
# Processing Record 27 of Set 7 | chilca
# Processing Record 28 of Set 7 | paamiut
# Processing Record 29 of Set 7 | sibolga
# Processing Record 30 of Set 7 | ahuimanu
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | darnah
# Processing Record 33 of Set 7 | andenes
# Processing Record 34 of Set 7 | mpika
# Processing Record 35 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 7 | victoria
# Processing Record 37 of Set 7 | vostok
# Processing Record 38 of Set 7 | verkhnyaya balkariya
# Processing Record 39 of Set 7 | marysville
# Processing Record 40 of Set 7 | yashalta
# Processing Record 41 of Set 7 | puerto carreno
# Processing Record 42 of Set 7 | saint anthony
# Processing Record 43 of Set 7 | khamgaon
# Processing Record 44 of Set 7 | isangel
# Processing Record 45 of Set 7 | prince rupert
# Processing Record 46 of Set 7 | pafos
# Processing Record 47 of Set 7 | boyolangu
# Processing Record 48 of Set 7 | vao
# Processing Record 49 of Set 7 | kathu
# Processing Record 50 of Set 7 | muhos
# Processing Record 1 of Set 8 | novoagansk
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | santa isabel do rio negro
# Processing Record 4 of Set 8 | gambela
# Processing Record 5 of Set 8 | la tuque
# Processing Record 6 of Set 8 | tasiilaq
# Processing Record 7 of Set 8 | ilulissat
# Processing Record 8 of Set 8 | tazovskiy
# Processing Record 9 of Set 8 | parana
# Processing Record 10 of Set 8 | quatre cocos
# Processing Record 11 of Set 8 | medea
# Processing Record 12 of Set 8 | guayaramerin
# Processing Record 13 of Set 8 | san matias
# Processing Record 14 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 8 | limoux
# Processing Record 16 of Set 8 | emerald
# Processing Record 17 of Set 8 | ugoofaaru
# Processing Record 18 of Set 8 | lazaro cardenas
# Processing Record 19 of Set 8 | ponta delgada
# Processing Record 20 of Set 8 | palana
# Processing Record 21 of Set 8 | koslan
# Processing Record 22 of Set 8 | bundaberg
# Processing Record 23 of Set 8 | yishui
# Processing Record 24 of Set 8 | sinnamary
# Processing Record 25 of Set 8 | zaliznychne
# Processing Record 26 of Set 8 | port moresby
# Processing Record 27 of Set 8 | taman
# Processing Record 28 of Set 8 | am timan
# Processing Record 29 of Set 8 | tautira
# Processing Record 30 of Set 8 | narsaq
# Processing Record 31 of Set 8 | hokitika
# Processing Record 32 of Set 8 | karaton
# Processing Record 33 of Set 8 | huarmey
# Processing Record 34 of Set 8 | alice springs
# Processing Record 35 of Set 8 | oktyabrskoye
# Processing Record 36 of Set 8 | ayan
# Processing Record 37 of Set 8 | vila
# Processing Record 38 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 8 | dasoguz
# Processing Record 41 of Set 8 | abu samrah
# Processing Record 42 of Set 8 | dillon
# Processing Record 43 of Set 8 | kiruna
# Processing Record 44 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 45 of Set 8 | poli
# Processing Record 46 of Set 8 | cascais
# Processing Record 47 of Set 8 | hohhot
# Processing Record 48 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 8 | mapiri
# Processing Record 50 of Set 8 | tyrma
# Processing Record 1 of Set 9 | leningradskiy
# Processing Record 2 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | cortez
# Processing Record 4 of Set 9 | belle fourche
# Processing Record 5 of Set 9 | qarchi gak
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | vrangel
# Processing Record 8 of Set 9 | santa fe
# Processing Record 9 of Set 9 | tual
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | nome
# Processing Record 12 of Set 9 | kirando
# Processing Record 13 of Set 9 | polyarnyy
# Processing Record 14 of Set 9 | zell am see
# Processing Record 15 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 9 | baiyin
# Processing Record 17 of Set 9 | madang
# Processing Record 18 of Set 9 | hyeres
# Processing Record 19 of Set 9 | college
# Processing Record 20 of Set 9 | bhavani
# Processing Record 21 of Set 9 | ulaangom
# Processing Record 22 of Set 9 | nelson bay
# Processing Record 23 of Set 9 | west wendover
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | lagos
# Processing Record 26 of Set 9 | port angeles
# Processing Record 27 of Set 9 | buchanan
# Processing Record 28 of Set 9 | severnyy
# Processing Record 29 of Set 9 | cruzeiro do sul
# Processing Record 30 of Set 9 | vila velha
# Processing Record 31 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 32 of Set 9 | pekalongan
# Processing Record 33 of Set 9 | mao
# Processing Record 34 of Set 9 | tura
# Processing Record 35 of Set 9 | notre-dame-du-lac
# Processing Record 36 of Set 9 | yoichi
# Processing Record 37 of Set 9 | havre-saint-pierre
# Processing Record 38 of Set 9 | gamboula
# Processing Record 39 of Set 9 | springdale
# Processing Record 40 of Set 9 | hervey bay
# Processing Record 41 of Set 9 | provideniya
# Processing Record 42 of Set 9 | verkhnevilyuysk
# Processing Record 43 of Set 9 | sao miguel do araguaia
# Processing Record 44 of Set 9 | san rafael
# Processing Record 45 of Set 9 | kaeo
# Processing Record 46 of Set 9 | east london
# Processing Record 47 of Set 9 | dwarka
# Processing Record 48 of Set 9 | hammerfest
# Processing Record 49 of Set 9 | pandan
# Processing Record 50 of Set 9 | erdenet
# Processing Record 1 of Set 10 | eberswalde
# Processing Record 2 of Set 10 | denpasar
# Processing Record 3 of Set 10 | san fernando
# Processing Record 4 of Set 10 | north bend
# Processing Record 5 of Set 10 | arlit
# Processing Record 6 of Set 10 | fort erie
# Processing Record 7 of Set 10 | san pedro
# Processing Record 8 of Set 10 | dodge city
# Processing Record 9 of Set 10 | yulara
# Processing Record 10 of Set 10 | riyadh
# Processing Record 11 of Set 10 | buala
# Processing Record 12 of Set 10 | moussoro
# Processing Record 13 of Set 10 | gimli
# Processing Record 14 of Set 10 | farmington
# Processing Record 15 of Set 10 | kendari
# Processing Record 16 of Set 10 | corrente
# Processing Record 17 of Set 10 | joshimath
# Processing Record 18 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 10 | bira
# Processing Record 20 of Set 10 | vardo
# Processing Record 21 of Set 10 | saint paul
# Processing Record 22 of Set 10 | shimoda
# Processing Record 23 of Set 10 | byron bay
# Processing Record 24 of Set 10 | flagstaff
# Processing Record 25 of Set 10 | ambovombe
# Processing Record 26 of Set 10 | kuroiso
# Processing Record 27 of Set 10 | korla
# Processing Record 28 of Set 10 | ondjiva
# Processing Record 29 of Set 10 | beringovskiy
# Processing Record 30 of Set 10 | raciborz
# Processing Record 31 of Set 10 | burley
# Processing Record 32 of Set 10 | sao gabriel da cachoeira
# Processing Record 33 of Set 10 | zhicheng
# Processing Record 34 of Set 10 | ouadda
# Processing Record 35 of Set 10 | severo-yeniseyskiy
# Processing Record 36 of Set 10 | kruisfontein
# Processing Record 37 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 10 | sisimiut
# Processing Record 39 of Set 10 | flin flon
# Processing Record 40 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 10 | namibe
# Processing Record 42 of Set 10 | urucara
# Processing Record 43 of Set 10 | calabar
# Processing Record 44 of Set 10 | mehamn
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | mpongwe
# Processing Record 47 of Set 10 | luncavita
# Processing Record 48 of Set 10 | shache
# Processing Record 49 of Set 10 | robinson
# Processing Record 50 of Set 10 | lingao
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | lisala
# Processing Record 3 of Set 11 | butterworth
# Processing Record 4 of Set 11 | bathurst
# Processing Record 5 of Set 11 | kimberley
# Processing Record 6 of Set 11 | tecozautla
# Processing Record 7 of Set 11 | immokalee
# Processing Record 8 of Set 11 | nhulunbuy
# Processing Record 9 of Set 11 | macia
# Processing Record 10 of Set 11 | mackay
# Processing Record 11 of Set 11 | grand forks
# Processing Record 12 of Set 11 | daru
# Processing Record 13 of Set 11 | den helder
# Processing Record 14 of Set 11 | mamlyutka
# Processing Record 15 of Set 11 | yongan
# Processing Record 16 of Set 11 | bandundu
# Processing Record 17 of Set 11 | pemba
# Processing Record 18 of Set 11 | lahijan
# Processing Record 19 of Set 11 | hamilton
# Processing Record 20 of Set 11 | teacapan
# Processing Record 21 of Set 11 | green river
# Processing Record 22 of Set 11 | imbituba
# Processing Record 23 of Set 11 | bay roberts
# Processing Record 24 of Set 11 | kidal
# Processing Record 25 of Set 11 | kristiinankaupunki
# Processing Record 26 of Set 11 | baghdad
# Processing Record 27 of Set 11 | solikamsk
# Processing Record 28 of Set 11 | maldonado
# Processing Record 29 of Set 11 | sambava
# Processing Record 30 of Set 11 | rio brilhante
# Processing Record 31 of Set 11 | winnemucca
# Processing Record 32 of Set 11 | saint-pierre
# Processing Record 33 of Set 11 | havoysund
# Processing Record 34 of Set 11 | gamba
# Processing Record 35 of Set 11 | moerai
# Processing Record 36 of Set 11 | meridian
# Processing Record 37 of Set 11 | russell
# Processing Record 38 of Set 11 | kavaratti
# Processing Record 39 of Set 11 | caravelas
# Processing Record 40 of Set 11 | baicheng
# Processing Record 41 of Set 11 | tari
# Processing Record 42 of Set 11 | gold coast
# Processing Record 43 of Set 11 | snasa
# Processing Record 44 of Set 11 | wewak
# Processing Record 45 of Set 11 | angoche
# Processing Record 46 of Set 11 | maragogi
# Processing Record 47 of Set 11 | rafai
# Processing Record 48 of Set 11 | thouars
# Processing Record 49 of Set 11 | danielskuil
# Processing Record 50 of Set 11 | viedma
# Processing Record 1 of Set 12 | yaan
# Processing Record 2 of Set 12 | paris
# Processing Record 3 of Set 12 | bolshaya sosnova
# Processing Record 4 of Set 12 | monster
# Processing Record 5 of Set 12 | hue
# Processing Record 6 of Set 12 | yazman
# Processing Record 7 of Set 12 | mareeba
# Processing Record 8 of Set 12 | margate
# Processing Record 9 of Set 12 | tilichiki
# Processing Record 10 of Set 12 | kieta
# Processing Record 11 of Set 12 | hovd
# Processing Record 12 of Set 12 | ojinaga
# Processing Record 13 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 12 | ilskiy
# Processing Record 15 of Set 12 | puerto narino
# Processing Record 16 of Set 12 | kabanjahe
# Processing Record 17 of Set 12 | amol
# Processing Record 18 of Set 12 | krasnoselkup
# Processing Record 19 of Set 12 | khandyga
# Processing Record 20 of Set 12 | oksfjord
# Processing Record 21 of Set 12 | kumluca
# Processing Record 22 of Set 12 | santa maria
# Processing Record 23 of Set 12 | muroto
# Processing Record 24 of Set 12 | nuuk
# Processing Record 25 of Set 12 | camana
# Processing Record 26 of Set 12 | sacramento
# Processing Record 27 of Set 12 | nibbar
# Processing Record 28 of Set 12 | valparaiso
# Processing Record 29 of Set 12 | chapais
# Processing Record 30 of Set 12 | marion
# Processing Record 31 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 32 of Set 12 | ercis
# Processing Record 33 of Set 12 | anadyr
# Processing Record 34 of Set 12 | bol
# Processing Record 35 of Set 12 | kirovskiy
# Processing Record 36 of Set 12 | bogorodskoye
# Processing Record 37 of Set 12 | coihaique
# Processing Record 38 of Set 12 | luganville
# Processing Record 39 of Set 12 | ayaviri
# Processing Record 40 of Set 12 | paita
# Processing Record 41 of Set 12 | biak
# Processing Record 42 of Set 12 | san luis
# Processing Record 43 of Set 12 | pak chong
# Processing Record 44 of Set 12 | aswan
# Processing Record 45 of Set 12 | qui nhon
# Processing Record 46 of Set 12 | ladario
# Processing Record 47 of Set 12 | burnie
# Processing Record 48 of Set 12 | suluq
# Processing Record 49 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 12 | kyabe
# Processing Record 1 of Set 13 | mitsamiouli
# Processing Record 2 of Set 13 | san roque
# Processing Record 3 of Set 13 | vyshchetarasivka
# Processing Record 4 of Set 13 | srandakan
# Processing Record 5 of Set 13 | yagodnoye
# Processing Record 6 of Set 13 | ovalle
# Processing Record 7 of Set 13 | gao
# Processing Record 8 of Set 13 | plettenberg bay
# Processing Record 9 of Set 13 | kungurtug
# Processing Record 10 of Set 13 | cruz alta
# Processing Record 11 of Set 13 | teshie
# Processing Record 12 of Set 13 | seymchan
# Processing Record 13 of Set 13 | akonolinga
# Processing Record 14 of Set 13 | samarai
# Processing Record 15 of Set 13 | zhezkazgan
# Processing Record 16 of Set 13 | poum
# Processing Record 17 of Set 13 | constitucion
# Processing Record 18 of Set 13 | gizo
# Processing Record 19 of Set 13 | beniganj
# Processing Record 20 of Set 13 | chitipa
# Processing Record 21 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 13 | mushie
# Processing Record 23 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 13 | mandurah
# Processing Record 25 of Set 13 | yeppoon
# Processing Record 26 of Set 13 | port-gentil
# Processing Record 27 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 13 | torit
# Processing Record 29 of Set 13 | orodara
# Processing Record 30 of Set 13 | zambezi
# Processing Record 31 of Set 13 | foz do iguacu
# Processing Record 32 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 33 of Set 13 | leh
# Processing Record 34 of Set 13 | cururupu
# Processing Record 35 of Set 13 | kindu
# Processing Record 36 of Set 13 | latung
# Processing Record 37 of Set 13 | puerto escondido
# Processing Record 38 of Set 13 | lichinga
# Processing Record 39 of Set 13 | pangnirtung
# Processing Record 40 of Set 13 | abnub
# Processing Record 41 of Set 13 | selcuk
# Processing Record 42 of Set 13 | savonlinna
# Processing Record 43 of Set 13 | saint-augustin
# Processing Record 44 of Set 13 | maltahohe
# Processing Record 45 of Set 13 | mildura
# Processing Record 46 of Set 13 | asmara
# Processing Record 47 of Set 13 | sabha
# Processing Record 48 of Set 13 | troitskoye
# Processing Record 49 of Set 13 | paracuru
# Processing Record 50 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 14 | okakarara
# Processing Record 2 of Set 14 | baikunthpur
# Processing Record 3 of Set 14 | lokoja
# Processing Record 4 of Set 14 | melita
# Processing Record 5 of Set 14 | pirgos
# Processing Record 6 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 14 | walvis bay
# Processing Record 8 of Set 14 | rizhao
# Processing Record 9 of Set 14 | aykhal
# Processing Record 10 of Set 14 | santa cruz del sur
# Processing Record 11 of Set 14 | andujar
# Processing Record 12 of Set 14 | kasimov
# Processing Record 13 of Set 14 | tegal
# Processing Record 14 of Set 14 | balikpapan
# Processing Record 15 of Set 14 | lewisville
# Processing Record 16 of Set 14 | puerto penasco
# Processing Record 17 of Set 14 | hede
# Processing Record 18 of Set 14 | kuandian
# Processing Record 19 of Set 14 | san carlos
# Processing Record 20 of Set 14 | aripuana
# Processing Record 21 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 14 | mehran
# Processing Record 23 of Set 14 | pochutla
# Processing Record 24 of Set 14 | basco
# Processing Record 25 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 14 | teya
# Processing Record 27 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 14 | kawalu
# Processing Record 29 of Set 14 | saint-georges
# Processing Record 30 of Set 14 | baruun-urt
# Processing Record 31 of Set 14 | atikokan
# Processing Record 32 of Set 14 | blythe
# Processing Record 33 of Set 14 | hopelchen
# Processing Record 34 of Set 14 | chabahar
# Processing Record 35 of Set 14 | vallenar
# Processing Record 36 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 14 | letlhakeng
# Processing Record 38 of Set 14 | rudnya
# Processing Record 39 of Set 14 | fort stewart
# Processing Record 40 of Set 14 | luwuk
# Processing Record 41 of Set 14 | otjiwarongo
# Processing Record 42 of Set 14 | karaj
# Processing Record 43 of Set 14 | half moon bay
# Processing Record 44 of Set 14 | maxixe
# Processing Record 45 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 14 | cam ranh
# Processing Record 47 of Set 14 | ambilobe
# Processing Record 48 of Set 14 | ruidoso
# Processing Record 49 of Set 14 | kupang
# Processing Record 50 of Set 14 | whitehorse
# Processing Record 1 of Set 15 | farafangana
# Processing Record 2 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 15 | harer
# Processing Record 4 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 15 | hendek
# Processing Record 6 of Set 15 | evensk
# Processing Record 7 of Set 15 | honiara
# Processing Record 8 of Set 15 | pimenta bueno
# Processing Record 9 of Set 15 | berceni
# Processing Record 10 of Set 15 | keetmanshoop
# Processing Record 11 of Set 15 | dogondoutchi
# Processing Record 12 of Set 15 | tombouctou
# Processing Record 13 of Set 15 | mapiripan
# Processing Record 14 of Set 15 | cairns
# Processing Record 15 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 16 of Set 15 | sur
# Processing Record 17 of Set 15 | nerang
# Processing Record 18 of Set 15 | ewo
# Processing Record 19 of Set 15 | chernyakhovsk
# Processing Record 20 of Set 15 | leninskoye
# Processing Record 21 of Set 15 | hobe sound
# Processing Record 22 of Set 15 | wicklow
# Processing Record 23 of Set 15 | ostrovnoy
# Processing Record 24 of Set 15 | taunggyi
# Processing Record 25 of Set 15 | davila
# Processing Record 26 of Set 15 | cap malheureux
# Processing Record 27 of Set 15 | demyansk
# Processing Record 28 of Set 15 | labuhan
# Processing Record 29 of Set 15 | port macquarie
# Processing Record 30 of Set 15 | morro bay
# Processing Record 31 of Set 15 | yenagoa
# Processing Record 32 of Set 15 | ures
# Processing Record 33 of Set 15 | yarmouth
# Processing Record 34 of Set 15 | koungou
# Processing Record 35 of Set 15 | bamiantong
# Processing Record 36 of Set 15 | vestmannaeyjar
# Processing Record 37 of Set 15 | natal
# Processing Record 38 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 15 | los llanos de aridane
# Processing Record 40 of Set 15 | kaspiyskiy
# Processing Record 41 of Set 15 | portland
# Processing Record 42 of Set 15 | inhambane
# Processing Record 43 of Set 15 | stornoway
# Processing Record 44 of Set 15 | jalu
# Processing Record 45 of Set 15 | klyuchi
# Processing Record 46 of Set 15 | superior
# Processing Record 47 of Set 15 | rengo
# Processing Record 48 of Set 15 | menomonie
# Processing Record 49 of Set 15 | oxelosund
# Processing Record 50 of Set 15 | barinas
# Processing Record 1 of Set 16 | montepuez
# Processing Record 2 of Set 16 | presidencia roque saenz pena
# Processing Record 3 of Set 16 | malwan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
citydata_df = pd.DataFrame(city_data)
#citydata_df.head(10)
citydata_df.to_csv(path_or_buf='WeatherPy_Database.csv', index_label='City_ID')
